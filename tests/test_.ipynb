# %%
print("t \t r")
# Out:
# t 	 r

# %%
ten = "trongdeptrai"

s = ten / "trong.txt"
s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 ten = "trongdeptrai"
#       2
# ----> 3 s = ten / "trong.txt"
#       4 s
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
def test_kieu_du_lieu(tmp_path):
    print("kieu du lieu cu no la", type(tmp_path))
    assert False

# %%
from moviepy.editor import VideoFileClip, AudioFileClip # dùng để cắt ghép video


video = VideoFileClip(r"../test_videos/test_video_1.mp4")

print(type(video))
# Out:
# <class 'moviepy.video.io.VideoFileClip.VideoFileClip'>
